# %%
import pandas as pd

# %%
df = pd.read_csv('data/classified.csv', index_col=0)

# %%
df.groupby('content_type').sum('ClientCreativeImpression')
# Out:
#               ClientCreativeImpression
# content_type
# Evergreen                      1213460
# Spontaneous                    2208036
