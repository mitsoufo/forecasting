# %%
import pandas as pd

# %%
df = pd.read_csv('data/black_friday_2024.csv')

# %%
df.head(1000).to_csv('original.csv')

# %%
df = pd.read_csv('data/black_friday_2025_claude.csv')
df.head(1000).to_csv('claude.csv')

# %%
df = pd.read_csv('data/black_friday_2026_daily_impression_forecast_by_content_type.csv')
df.head(1000).to_csv('forecast_content.csv')

# %%
df = pd.read_csv('data/black_friday_2026_daily_impression_forecast_by_topic.csv')
df.head(1000).to_csv('forecast_topic.csv')

# %%
df = pd.read_csv('data/black_friday_with_topics.csv')
df.head(1000).to_csv('topic.csv')
